# %% [markdown]
# <a href="https://colab.research.google.com/github/bruno353/Data_Science_Projects/blob/main/Base_INNO2.0_tratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Cópia de Base Inno Processo_Final_2021.xlsx - Base Final Chris.csv')

# %%
df.head()
# Out:
#    Base Nome da startup  ... Rollout Observações
# 0  Inno              99  ...     NaN         NaN
# 1   Abs            1927  ...     NaN         NaN
# 2  Inno            3778  ...     NaN         NaN
# 3  Inno     #TchauCarro  ...     NaN         NaN
# 4  Inno  (Assis)compras  ...     NaN         NaN
#
# [5 rows x 19 columns]

# %%
df['Tamanho time'].value_counts()
# Out:
# 1-5                                                                             5246
# 6-10                                                                            2893
# 11-20                                                                            387
# 21-50                                                                            371
# 51-100                                                                            63
# 1-5;6-10                                                                          55
# 101-200                                                                           54
# N/D                                                                               28
# 6-10;1-5                                                                          26
# 201-500                                                                           18
# 1-5;11-20                                                                         17
# ...

# %%
df['Cidade'].value_counts()
# Out:
# São Paulo - SP                       2012
#  -                                   1903
# Rio de Janeiro - RJ                   493
# Belo Horizonte - MG                   460
# Porto Alegre - RS                     392
#                                      ...
# Trindade - GO                           1
# Florianópolis - SC                      1
# Maceió - AL \nRibeirão Preto - SP       1
# Marau - RS                              1
# Nova Prata - RS                         1
# Name: Cidade, Length: 515, dtype: int64

# %%
df['Categoria'].value_counts()
# Out:
# 0                                         2389
# Educação                                   604
# Finanças                                   457
# Outros                                     431
# Saúde e Bem-estar                          410
#                                           ...
# Mobile, Vendas e Marketing                   1
# Varejo / Atacado,Outros                      1
# Eventos e Turismo, Comunicação e Mídia       1
# Direito, Internet                            1
# Eventos e Turismo, E-commerce                1
# Name: Categoria, Length: 151, dtype: int64

# %%
df['Modelo de negócios'].value_counts()
# Out:
# 0                                                                                                                                                                                                                         4533
# SaaS                                                                                                                                                                                                                      2029
# --                                                                                                                                                                                                                        1204
# Marketplace                                                                                                                                                                                                                899
# ...

# %% [markdown]
# ##Porcentagem de colunas com valores faltando

# %%
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                        Total   Percent
# Rollout                14830  0.994968
# Pilotos                14712  0.987051
# Observações            14708  0.986783
# Tags                    5877  0.394297
# Ano fundação            5859  0.393090
# Categoria               5762  0.386582
# Cidade                  5714  0.383361
# Tamanho time            5645  0.378732
# Telefone                5030  0.337471
# Fonte                   4778  0.320564
# E-mail                  4668  0.313183
# Linkedin empreendedor   4291  0.287890
# Modelo de negócios      3444  0.231063
# Nome empreendedor       3241  0.217444
# Maturidade              2297  0.154109
# Descrição longa           23  0.001543
# Website                    9  0.000604
# Base                       9  0.000604
# Nome da startup            1  0.000067

# %% [markdown]
# ##Tratamento e junção de dados

# %%
df_edtech = pd.read_excel('/content/EDTECHS.xlsx')

# %%
df_edtech.head()
# Out:
#   Nome da startup  ...                            Tags
# 0        Escol.as  ...  Analytics no Setor Educacional
# 1     Evolucional  ...  Analytics no Setor Educacional
# 2    Explica Mais  ...  Analytics no Setor Educacional
# 3       Foreleven  ...  Analytics no Setor Educacional
# 4          Geekie  ...  Analytics no Setor Educacional
#
# [5 rows x 4 columns]

# %%
names = df['Nome da startup'].value_counts()
names[names > 1]
# Out:
# BIPP            2
# Gorila App      2
# TecSUS          2
# Join            2
# Simplifique     2
# PlanXP          2
# Partiu          2
# Sync Company    2
# Name: Nome da startup, dtype: int64

# %%
df_edtech.rename(columns={'Empresa': 'Nome da startup'}, inplace=True)

# %%
df_edtech.rename(columns={'Descrição': 'Descrição longa'}, inplace=True)

# %%
df_edtech.rename(columns={'Site':'Website'},inplace=True)

# %%
df_edtech.rename(columns={'TAG':'Tags'},inplace=True)

# %%
m = pd.merge(df, df_edtech, how = 'outer')

# %%
m.head()
# Out:
#    Base Nome da startup  ... Rollout Observações
# 0  Inno              99  ...     NaN         NaN
# 1   Abs            1927  ...     NaN         NaN
# 2  Inno            3778  ...     NaN         NaN
# 3  Inno     #TchauCarro  ...     NaN         NaN
# 4  Inno  (Assis)compras  ...     NaN         NaN
#
# [5 rows x 19 columns]

# %%
m[m['Nome da startup']=='Escol.as']
# Out:
#       Base Nome da startup  ... Rollout Observações
# 14905  NaN        Escol.as  ...     NaN         NaN
#
# [1 rows x 19 columns]

# %%
#152 empresas já presente no dataset
names = m['Nome da startup'].value_counts()
names[names>1]
# Out:
# Estudar Com Você    2
# Estudologia         2
# American Insight    2
# Gomining            2
# UpBrain             2
#                    ..
# VRMonkey            2
# Eskolare            2
# Speak to Share      2
# Lemonaid            2
# Me Salva!           2
# Name: Nome da startup, Length: 160, dtype: int64

# %%
m[m['Nome da startup']=='Me Salva!']
# Out:
#       Base Nome da startup  ... Rollout Observações
# 8414   Abs       Me Salva!  ...     NaN         NaN
# 15310  NaN       Me Salva!  ...     NaN         NaN
#
# [2 rows x 19 columns]

# %%
tre = m.loc[m['Nome da startup'].duplicated(),:]

# %%
print(tre)
# Out:
#        Base Nome da startup  ... Rollout Observações
# 1779    Abs            BIPP  ...     NaN         NaN
# 5928    Abs      Gorila App  ...     NaN         NaN
# 7285    Abs            Join  ...     NaN         NaN
# 10218   Abs          Partiu  ...     NaN         NaN
# 10542  Inno          PlanXP  ...     NaN         NaN
# ...     ...             ...  ...     ...         ...
# 15309   NaN          Kuadro  ...     NaN         NaN
# 15310   NaN       Me Salva!  ...     NaN         NaN
# 15312   NaN    OAB de Bolso  ...     NaN         NaN
# 15314   NaN  Redação Online  ...     NaN         NaN
# 15315   NaN          Stoodi  ...     NaN         NaN
#
# [160 rows x 19 columns]

# %%
with pd.option_context('display.max_rows', None,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(tre)
# Out:
#        Base            Nome da startup  \
# 1779    Abs                       BIPP
# 5928    Abs                 Gorila App
# 7285    Abs                       Join
# 10218   Abs                     Partiu
# 10542  Inno                     PlanXP
# 12200   Abs                Simplifique
# 12941  Inno               Sync Company
# 13149   Abs                     TecSUS
# 14906   NaN                Evolucional
# 14908   NaN                  Foreleven
# 14909   NaN                     Geekie
# 14910   NaN                   Indeorum
# 14911   NaN                   Lemonaid
# 14914   NaN                 Mercadoedu
# 14915   NaN                      Movva
# 14919   NaN                     Studos
# 14923   NaN                  AprendeAí
# 14926   NaN                    Descola
# 14928   NaN                 EducaPoint
# 14929   NaN                Escola Agro
# 14932   NaN           Future Education
# 14939   NaN                    Kanttum
# 14940   NaN                       Kuau
# ...
